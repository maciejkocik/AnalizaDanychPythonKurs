# %% [markdown]
# # <span style="color:#0f766e; font-weight:700;">Analiza Danych (Python) - Lekcja 3</span>
#
# 1. [Czym jest DataFrame?](#1.-Czym-jest-DataFrame?)
# 2. [Najważniejsze operacje na DataFrame](#2.-Najważniejsze-operacje-na-DataFrame)
# 3. [Dane do ćwiczeń](#3.-Dane-do-ćwiczeń)
# 4. [Zadania](#4.-Zadania)
# 5. [Najczęstsze błędy](#Najczęstsze-błędy)

# %% [markdown]
# # <span style="color:#0f766e; font-weight:700;">1. Czym jest DataFrame?</span>
#
# `DataFrame` to podstawowa struktura danych w `pandas`.
#
# Najprościej:
# - jest to **tabela** z wierszami i kolumnami,
# - każda kolumna ma nazwę,
# - każda kolumna ma typ danych (`dtype`),
# - można na niej wykonywać filtrowanie, agregacje, łączenie tabel i przekształcenia.
#
# W praktyce `DataFrame` łączy w sobie cechy:
# - arkusza kalkulacyjnego,
# - tabeli SQL,
# - obiektu programistycznego, na którym można budować cały pipeline analityczny.
#
# ## <span style="color:#0f766e; font-weight:700;">Jak myśleć o DataFrame?</span>
#
# - **wiersz** = jedna obserwacja / rekord,
# - **kolumna** = jedna zmienna / cecha,
# - **indeks** = etykieta wiersza,
# - **dtype** = techniczna reprezentacja danych w pamięci.
#
# Przykłady:
# - tabela pracowników,
# - tabela transakcji,
# - wyniki ankiety,
# - logi eksperymentu.

# %% [markdown]
# # <span style="color:#0f766e; font-weight:700;">2. Najważniejsze operacje na DataFrame</span>
#
# ## <span style="color:#0f766e; font-weight:700;">Tworzenie i wczytywanie</span>
#
# Najczęściej używane wejścia:
# - `pd.read_csv()` - wczytuje dane z pliku CSV do `DataFrame`.
# - `pd.read_excel()` - wczytuje dane z pliku Excel (`.xlsx`, `.xls`).
# - `pd.read_json()` - wczytuje dane zapisane w formacie JSON.
# - `pd.DataFrame()` - tworzy `DataFrame` ręcznie, np. ze słownika lub listy.
#
# Szybka diagnostyka po wczytaniu:
# - `head()` - pokazuje pierwsze wiersze tabeli.
# - `tail()` - pokazuje ostatnie wiersze tabeli.
# - `sample()` - losuje przykładowe rekordy do szybkiego podglądu.
# - `shape` - zwraca liczbę wierszy i kolumn.
# - `info()` - pokazuje typy kolumn, braki danych i podstawową strukturę.
# - `dtypes` - zwraca typ danych każdej kolumny.
# - `describe()` - liczy podstawowe statystyki opisowe dla kolumn liczbowych.
#
# Przykład:
# ```python
# import pandas as pd
#
# df = pd.read_csv('plik.csv')
# df.head()
# df.info()
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Wybieranie danych</span>
#
# Najważniejsze narzędzia:
# - wybór kolumn: `df[['kol1', 'kol2']]` - zwraca nowy `DataFrame` z wybranymi kolumnami.
# - wybór jednej kolumny: `df['kol1']` - zwraca pojedynczą serię (`Series`).
# - wybór etykietami: `df.loc[...]` - wybiera dane po nazwach wierszy i kolumn.
# - wybór po pozycjach: `df.iloc[...]` - wybiera dane po numerach pozycji.
# - filtrowanie logiczne: `df[df['wiek'] > 30]` - zostawia tylko rekordy spełniające warunek.
# - zapytania tekstowe: `df.query(...)` - pozwala filtrować dane składnią podobną do SQL.
#
# Przykład:
# ```python
# df.loc[df['salary_pln'] > 10000, ['department', 'salary_pln']]
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Czyszczenie i transformacje</span>
#
# Najważniejsze metody:
# - `rename()` - zmienia nazwy kolumn lub indeksu.
# - `drop()` - usuwa wskazane kolumny albo wiersze.
# - `dropna()` - usuwa wiersze lub kolumny z brakami danych.
# - `fillna()` - uzupełnia braki danych wskazaną wartością.
# - `astype()` - konwertuje kolumnę na inny typ danych.
# - `assign()` - dodaje nową kolumnę lub kilka kolumn w jednym kroku.
# - `replace()` - zamienia wskazane wartości na inne.
# - `sort_values()` - sortuje dane według wartości w kolumnie.
# - `sort_index()` - sortuje dane według indeksu.
# - `reset_index()` - przywraca zwykły indeks liczbowy.
# - `set_index()` - ustawia wybraną kolumnę jako indeks.
#
# Przykład:
# ```python
# df = df.rename(columns={'salary_pln': 'salary'})
# df = df.sort_values('salary', ascending=False)
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Agregacje i grupowanie</span>
#
# Najważniejsze:
# - `value_counts()` - liczy częstość występowania wartości w kolumnie.
# - `groupby()` - dzieli dane na grupy według jednej lub kilku kolumn.
# - `agg()` - pozwala policzyć kilka agregacji naraz.
# - `mean()` - liczy średnią.
# - `median()` - liczy medianę.
# - `sum()` - liczy sumę.
# - `min()` - zwraca wartość minimalną.
# - `max()` - zwraca wartość maksymalną.
# - `std()` - liczy odchylenie standardowe.
# - `nunique()` - liczy liczbę unikalnych wartości.
#
# Przykład:
# ```python
# df.groupby('department').agg(
#     salary_mean=('salary_pln', 'mean'),
#     people=('employee_id', 'count')
# )
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Łączenie tabel</span>
#
# Najważniejsze:
# - `merge()` - łączy dwie tabele po wspólnym kluczu.
# - `join()` - wygodne łączenie po indeksie lub kluczach.
# - `concat()` - skleja tabele pionowo albo poziomo.
#
# Przykład:
# ```python
# df = employees.merge(departments, on='department', how='left')
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Zmiana kształtu tabeli</span>
#
# Najważniejsze:
# - `pivot_table()` - tworzy tabelę przestawną z agregacją.
# - `pivot()` - przekształca układ danych bez agregowania.
# - `melt()` - zamienia układ szeroki na długi.
#
# Przykład:
# ```python
# scores_long = scores.melt(
#     id_vars='employee_id',
#     var_name='quarter',
#     value_name='score'
# )
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Operacje tekstowe i daty</span>
#
# Bardzo ważne accesory:
# - `.str` - udostępnia metody do pracy na tekście w kolumnach.
# - `.dt` - udostępnia metody do pracy na datach i czasie.
#
# Najczęściej używane:
# - `str.lower()` - zamienia tekst na małe litery.
# - `str.strip()` - usuwa zbędne spacje z początku i końca tekstu.
# - `str.contains()` - sprawdza, czy tekst zawiera wzorzec.
# - `to_datetime()` - konwertuje tekst na datę.
# - `dt.year` - wyciąga rok z daty.
# - `dt.month` - wyciąga numer miesiąca.
# - `dt.day_name()` - zwraca nazwę dnia tygodnia.
#
# Przykład:
# ```python
# df['hire_date'] = pd.to_datetime(df['hire_date'])
# df['year'] = df['hire_date'].dt.year
# ```
#
# ## <span style="color:#0f766e; font-weight:700;">Wykonywalne przykłady</span>
#
# Poniżej znajdziesz wykonywalne przykłady kodu dla każdej najważniejszej grupy operacji na `DataFrame`. Każdą komórkę można uruchomić niezależnie.

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 1: Wczytywanie i szybka diagnostyka</span>
#
# Ta komórka pokazuje, jak wczytać dane i natychmiast sprawdzić ich strukturę: `head`, `tail`, `sample`, `shape`, `info`, `dtypes`, `describe`.

# %%
import pandas as pd

# Wczytujemy plik CSV do obiektu DataFrame.
# Parametr: ścieżka tekstowa 'dane_lekcja3/employees.csv' wskazuje plik źródłowy.
df = pd.read_csv('dane_lekcja3/employees.csv')

# head() pokazuje pierwsze 5 wierszy.
# Brak parametru oznacza domyślnie n=5.
print('HEAD:')
print(df.head())
print()

# tail() pokazuje ostatnie 5 wierszy.
# Brak parametru oznacza domyślnie n=5.
print('TAIL:')
print(df.tail())
print()

# sample() losuje przykładowe rekordy.
# Parametr 3 oznacza liczbę losowanych wierszy.
# Parametr random_state=42 ustawia ziarno losowości, więc wynik będzie powtarzalny.
print('SAMPLE (3):')
print(df.sample(3, random_state=42))
print()

# shape nie jest funkcją, tylko atrybutem.
# Zwraca krotkę: (liczba_wierszy, liczba_kolumn).
print('SHAPE:', df.shape)
print()

# info() pokazuje strukturę tabeli.
# Widzimy liczbę niepustych wartości, typy danych i przybliżone zużycie pamięci.
print('INFO:')
df.info()
print()

# dtypes zwraca serię z typami każdej kolumny.
print('DTYPES:')
print(df.dtypes)
print()

# describe() liczy statystyki opisowe.
# Parametr include='all' każe uwzględnić także kolumny tekstowe.
# .T transponuje wynik, żeby łatwiej czytać statystyki dla każdej kolumny w wierszu.
# head(10) ogranicza wydruk do pierwszych 10 wierszy wyniku.
print('DESCRIBE:')
print(df.describe(include='all').T.head(10))
# Out:
# HEAD:
#    employee_id first_name  last_name department     city  age  salary_pln  \
# 0            1     Szymon  Zielinski      sales  Wroclaw   31    12928.65
# 1            2      Marta   Kowalski         hr   Krakow   25     9648.33
# 2            3        Iga  Kaczmarek         hr   Poznan   23    10907.36
# 3            4    Roksana      Mazur        ops  Wroclaw   55    10229.72
# 4            5     Celina  Kaczmarek  analytics   Poznan   57     8448.04
#
#    bonus_pct  performance_score  projects_count  remote_days   hire_date  \
# 0      0.076               4.23               9            1  2021-02-09
# 1      0.068               3.28               8           13  2024-10-02
# 2      0.166               2.76               4           13  2020-05-17
# 3      0.011               3.06               8            0  2023-05-31
# 4      0.163               2.60               1            5  2024-05-26
#
#    is_manager contract_type
# 0           0      Zlecenie
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 2: Wybieranie kolumn, filtrowanie, `loc`, `iloc`, `query`</span>
#
# Ta komórka pokazuje różnicę między wyborem kolumn, filtrowaniem warunkiem, wyborem po etykietach (`loc`) i po pozycjach (`iloc`).

# %%
import pandas as pd

# Wczytujemy dane pracowników do DataFrame.
df = pd.read_csv('dane_lekcja3/employees.csv')

# Wybór kilku kolumn przez listę nazw.
# Podwójne nawiasy kwadratowe zwracają DataFrame, a nie pojedynczą serię.
subset = df[['employee_id', 'department', 'city', 'salary_pln']]
print('WYBRANE KOLUMNY:')
print(subset.head())
print()

# Filtrowanie logiczne.
# Warunek df['salary_pln'] > 12000 tworzy serię wartości True/False.
# DataFrame[warunek] zostawia tylko wiersze, dla których warunek jest True.
high_salary = df[df['salary_pln'] > 12000]
print('PENSJA > 12000:')
print(high_salary[['employee_id', 'department', 'salary_pln']].head())
print()

# loc wybiera dane po etykietach.
# Pierwszy argument 0:4 oznacza zakres wierszy po indeksie.
# Drugi argument to lista nazw kolumn, które chcemy pokazać.
print('LOC (wiersze 0:4, konkretne kolumny):')
print(df.loc[0:4, ['first_name', 'last_name', 'salary_pln']])
print()

# iloc wybiera dane po pozycjach liczbowych.
# Pierwszy argument 0:5 oznacza wiersze o pozycjach 0-4.
# Drugi argument 1:4 oznacza kolumny o pozycjach 1-3.
print('ILOC (wiersze 0:5, kolumny 1:4):')
print(df.iloc[0:5, 1:4])
print()

# query() pozwala zapisać filtr jako czytelny tekst.
# Wewnątrz stringa odwołujemy się do nazw kolumn bez df['...'].
# Wynik dodatkowo ograniczamy do kilku kolumn.
print('QUERY department == analytics and salary_pln > 10000:')
print(
    df.query("department == 'analytics' and salary_pln > 10000")
      [['employee_id', 'department', 'salary_pln']]
      .head()
)

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 3: Transformacje, zmiana nazw, nowe kolumny, sortowanie, indeks</span>
#
# Ta komórka pokazuje typowy pipeline przekształceń na `DataFrame`.

# %%
import pandas as pd

# Wczytujemy dane pracowników.
df = pd.read_csv('dane_lekcja3/employees.csv')

# rename() zmienia nazwy kolumn.
# Parametr columns przyjmuje słownik: stara_nazwa -> nowa_nazwa.
df = df.rename(columns={'salary_pln': 'salary'})

# assign() dodaje nowe kolumny w jednym kroku.
# annual_salary to pensja miesięczna * 12.
# bonus_value to liczbowy odpowiednik procentowego bonusu.
df = df.assign(
    annual_salary=df['salary'] * 12,
    bonus_value=df['salary'] * df['bonus_pct']
)

# replace() podmienia wskazane wartości.
# Tutaj zamieniamy skrót 'UoP' na pełniejszą nazwę.
# Parametr przekazujemy jako słownik: stara_wartość -> nowa_wartość.
df['contract_type'] = df['contract_type'].replace({'UoP': 'umowa_o_prace'})

# sort_values() sortuje tabelę po wartości w kolumnie.
# Parametr 'annual_salary' wskazuje kolumnę sortowania.
# Parametr ascending=False ustawia sortowanie malejące.
sorted_df = df.sort_values('annual_salary', ascending=False)
print('PO SORTOWANIU:')
print(sorted_df[['employee_id', 'salary', 'annual_salary']].head())
print()

# set_index() ustawia wskazaną kolumnę jako indeks wierszy.
# Parametr 'employee_id' mówi, która kolumna ma stać się indeksem.
indexed = sorted_df.set_index('employee_id')
print('PO SET_INDEX:')
print(indexed.head(3))
print()

# reset_index() przywraca zwykły indeks liczbowy i zwraca dawny indeks jako kolumnę.
reset_back = indexed.reset_index()
print('PO RESET_INDEX:')
print(reset_back.head(3))

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 4: `value_counts`, `groupby`, `agg`, `nunique`</span>
#
# Ta komórka pokazuje najczęstsze operacje podsumowujące na `DataFrame`.

# %%
import pandas as pd

# Wczytujemy tabelę pracowników.
df = pd.read_csv('dane_lekcja3/employees.csv')

# value_counts() liczy wystąpienia każdej wartości w kolumnie.
print('LICZEBNOSC DEPARTAMENTOW:')
print(df['department'].value_counts())
print()

# nunique() liczy liczbę unikalnych wartości w kolumnie.
print('LICZBA UNIKALNYCH MIAST:', df['city'].nunique())
print()

# groupby('department') dzieli dane na grupy według działu.
# agg() liczy wiele agregacji jednocześnie.
# Każdy wpis ma postać: nowa_nazwa_kolumny=(kolumna_wejściowa, funkcja_agregująca).
summary = df.groupby('department').agg(
    employees=('employee_id', 'count'),
    salary_mean=('salary_pln', 'mean'),
    salary_median=('salary_pln', 'median'),
    performance_mean=('performance_score', 'mean')
)

# sort_values() porządkuje wynik po średniej pensji malejąco.
summary = summary.sort_values('salary_mean', ascending=False)

print('PODSUMOWANIE WG DEPARTMENT:')
print(summary)

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 5: `merge`, `join`, `concat`</span>
#
# Ta komórka pokazuje trzy różne sposoby łączenia danych.

# %%
import pandas as pd

# Wczytujemy dwie tabele, które będziemy łączyć.
employees = pd.read_csv('dane_lekcja3/employees.csv')
departments = pd.read_csv('dane_lekcja3/departments.csv')

# merge() łączy tabele po wspólnym kluczu.
# Parametr on='department' mówi, że kluczem jest kolumna department po obu stronach.
# Parametr how='left' oznacza: zachowaj wszystkie rekordy z lewej tabeli (employees).
# Parametr indicator=True dodaje kolumnę _merge z informacją o dopasowaniu rekordów.
merged = employees.merge(departments, on='department', how='left', indicator=True)
print('MERGE:')
print(merged[['employee_id', 'department', 'director', '_merge']].head())
print()

# join() jest wygodny, gdy łączymy po indeksie.
# Najpierw ustawiamy w obu tabelach department jako indeks.
emp_idx = employees.set_index('department')
dep_idx = departments.set_index('department')

# Parametr how='left' działa analogicznie jak w merge.
# Parametr rsuffix='_dept' dodaje sufiks do kolumn konfliktujących nazwami po prawej stronie.
joined = emp_idx.join(dep_idx, how='left', rsuffix='_dept')
print('JOIN:')
print(joined[['employee_id', 'director', 'budget_k_pln']].head())
print()

# concat() skleja obiekty razem.
# Tutaj bierzemy dwa fragmenty tej samej tabeli.
part_a = employees.head(2)
part_b = employees.tail(2)

# Parametr axis=0 oznacza sklejanie pionowe, czyli dokładanie wierszy.
concatenated = pd.concat([part_a, part_b], axis=0)
print('CONCAT:')
print(concatenated[['employee_id', 'department']])

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 6: `melt`, `pivot`, `pivot_table`</span>
#
# Ta komórka pokazuje zmianę kształtu danych: z układu szerokiego na długi i budowę tabeli przestawnej.

# %%
import pandas as pd

# Wczytujemy dane w układzie szerokim (wide).
scores = pd.read_csv('dane_lekcja3/employee_scores_wide.csv')

# melt() zamienia wiele kolumn wyników na układ długi.
# Parametr id_vars='employee_id' wskazuje kolumnę identyfikującą rekord.
# Parametr var_name='quarter' tworzy nową kolumnę z dawnymi nazwami kolumn.
# Parametr value_name='score' tworzy kolumnę z wartościami.
scores_long = scores.melt(
    id_vars='employee_id',
    var_name='quarter',
    value_name='score'
)
print('MELT (wide -> long):')
print(scores_long.head())
print()

# Przygotowujemy małą, ale kompletną próbkę do demonstracji pivot().
# Bierzemy 3 identyfikatory, dla których istnieją wszystkie 4 kwartały.
example_ids = scores['employee_id'].head(3).tolist()
small = scores_long[scores_long['employee_id'].isin(example_ids)].copy()

# pivot() zamienia układ długi z powrotem na szeroki.
# Parametr index='employee_id' ustawia wiersze.
# Parametr columns='quarter' tworzy kolumny z nazw kwartałów.
# Parametr values='score' wskazuje, jakie wartości wypełniają komórki.
pivoted = small.pivot(index='employee_id', columns='quarter', values='score')
print('PIVOT (long -> wide, kompletna probka):')
print(pivoted)
print()

# Wczytujemy drugą tabelę do demonstracji pivot_table().
hours = pd.read_csv('dane_lekcja3/monthly_hours.csv')

# pivot_table() działa jak tabela przestawna z agregacją.
# Parametr index='month' ustawia wiersze tabeli wynikowej.
# Parametr values='billable_hours' wskazuje kolumnę do agregacji.
# Parametr aggfunc='mean' mówi, że liczymy średnią.
pivot_tbl = hours.pivot_table(
    index='month',
    values='billable_hours',
    aggfunc='mean'
)
print('PIVOT_TABLE (srednie billable_hours wg month):')
print(pivot_tbl)
# Out:
# MELT (wide -> long):
#    employee_id   quarter  score
# 0            1  score_q1   56.9
# 1            2  score_q1   73.6
# 2            3  score_q1   73.8
# 3            4  score_q1   86.8
# 4            5  score_q1   62.0
#
# PIVOT (long -> wide, kompletna probka):
# quarter      score_q1  score_q2  score_q3  score_q4
# employee_id
# 1                56.9      96.9      66.7      86.6
# 2                73.6      61.1      74.2      97.1
# 3                73.8      51.7      53.9      99.3
#
# PIVOT_TABLE (srednie billable_hours wg month):
#          billable_hours
# month
# 2025-01      110.745378
# 2025-02      108.096266
# 2025-03      109.794262
# 2025-04      110.821739
# 2025-05      112.606818
# 2025-06      106.422026

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Przykład 7: `.str`, `pd.to_datetime()`, `.dt`</span>
#
# Ta komórka pokazuje pracę z tekstem i datami na kolumnach `DataFrame`.

# %%
import pandas as pd

# Wczytujemy dane pracowników.
df = pd.read_csv('dane_lekcja3/employees.csv')

# Operacje tekstowe przez accessor .str.
# str.lower() zamienia tekst na małe litery.
# str.strip() usuwa zbędne spacje z początku i końca tekstu.
df['first_name_clean'] = df['first_name'].str.lower().str.strip()
df['last_name_clean'] = df['last_name'].str.lower().str.strip()

# Łączymy dwie kolumny tekstowe w jedną nową kolumnę full_name.
df['full_name'] = df['first_name_clean'] + ' ' + df['last_name_clean']

# str.contains('a') sprawdza, czy w tekście występuje litera 'a'.
# Wynik to seria wartości True/False.
df['is_name_with_a'] = df['full_name'].str.contains('a')

print('OPERACJE TEKSTOWE:')
print(df[['first_name', 'last_name', 'full_name', 'is_name_with_a']].head())
print()

# pd.to_datetime() konwertuje tekst na typ daty.
# Parametr przekazujemy jako serię, którą chcemy przekonwertować.
df['hire_date'] = pd.to_datetime(df['hire_date'])

# Accessor .dt udostępnia operacje na dacie.
# dt.year wyciąga rok.
# dt.month wyciąga numer miesiąca.
# dt.day_name() zwraca nazwę dnia tygodnia.
df['hire_year'] = df['hire_date'].dt.year
df['hire_month'] = df['hire_date'].dt.month
df['hire_day_name'] = df['hire_date'].dt.day_name()

print('OPERACJE NA DATACH:')
print(df[['hire_date', 'hire_year', 'hire_month', 'hire_day_name']].head())

# %% [markdown]
# # <span style="color:#0f766e; font-weight:700;">3. Dane do ćwiczeń</span>
#
# Pliki znajdują się w folderze `dane_lekcja3/`:
#
# - `employees.csv` (700 wierszy)
# - `departments.csv` (8 wierszy)
# - `employee_scores_wide.csv` (500 wierszy)
# - `monthly_hours.csv` (1400 wierszy)
# - `README.md`

# %% [markdown]
# # <span style="color:#0f766e; font-weight:700;">4. Zadania</span>

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 1</span>
#
# Wczytaj `employees.csv` i wykonaj pełną szybką diagnostykę tabeli: `head`, `tail`, `sample`, `shape`, `info`, `dtypes`, `describe`.
#
# Wymagane funkcje/parametry:
# - `pd.read_csv()` - wczytuje plik CSV do `DataFrame`.
# - `head()` - pokazuje pierwsze wiersze tabeli.
# - `tail()` - pokazuje ostatnie wiersze tabeli.
# - `sample()` - losuje kilka przykładowych rekordów.
# - `shape` - podaje liczbę wierszy i kolumn.
# - `info()` - pokazuje strukturę tabeli, typy i braki danych.
# - `dtypes` - pokazuje typ każdej kolumny.
# - `describe()` - liczy podstawowe statystyki opisowe.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# - https://pandas.pydata.org/docs/reference/frame.html

# %%
# tutaj dodaj swój kod

df = pd.read_csv('dane_lekcja3/employees.csv')
df.head()

print('HEAD:')
print(df.head())
print()

print('TAIL:')
print(df.tail())
print()

print('SAMPLE (3):')
print(df.sample(3, random_state=42))
print()

print('SHAPE:', df.shape)
print()

print('INFO:')
df.info()
print()

print('DTYPES:')
print(df.dtypes)
print()


print('DESCRIBE:')
print(df.describe(include='all').T.head(10))
# Out:
# HEAD:
#    employee_id first_name  last_name department     city  age  salary_pln  \
# 0            1     Szymon  Zielinski      sales  Wroclaw   31    12928.65
# 1            2      Marta   Kowalski         hr   Krakow   25     9648.33
# 2            3        Iga  Kaczmarek         hr   Poznan   23    10907.36
# 3            4    Roksana      Mazur        ops  Wroclaw   55    10229.72
# 4            5     Celina  Kaczmarek  analytics   Poznan   57     8448.04
#
#    bonus_pct  performance_score  projects_count  remote_days   hire_date  \
# 0      0.076               4.23               9            1  2021-02-09
# 1      0.068               3.28               8           13  2024-10-02
# 2      0.166               2.76               4           13  2020-05-17
# 3      0.011               3.06               8            0  2023-05-31
# 4      0.163               2.60               1            5  2024-05-26
#
#    is_manager contract_type
# 0           0      Zlecenie
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 2</span>
#
# Wybierz tylko kolumny `department`, `city`, `salary_pln`, `performance_score`. Następnie pokaż pracowników z pensją powyżej 12000 PLN.
#
# Wymagane funkcje/parametry:
# - wybór kolumn `df[[...]]` - tworzy nowy `DataFrame` z wybranymi kolumnami.
# - `loc[]` - pozwala filtrować i wybierać konkretne kolumny jednocześnie.
# - filtrowanie logiczne - zostawia tylko rekordy spełniające warunek.
# - `query()` (opcjonalnie) - pozwala zapisać filtr w czytelnej formie tekstowej.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
subset = df[['department', 'city', 'salary_pln', 'performance_score']]
print('WYBRANE KOLUMNY:')
print(subset.head())
print()

# Filtrowanie logiczne: pracownicy z pensją powyżej 12000 PLN
high_salary = subset[subset['salary_pln'] > 12000]
print('PRACOWNICY Z PENSJĄ > 12000 PLN:')
print(high_salary.head())
print()

# To samo przy użyciu loc[]
high_salary_loc = df.loc[df['salary_pln'] > 12000, ['department', 'city', 'salary_pln', 'performance_score']]
print('LOC - PRACOWNICY Z PENSJĄ > 12000 PLN:')
print(high_salary_loc.head())
print()

# To samo przy użyciu query()
high_salary_query = df.query('salary_pln > 12000')[['department', 'city', 'salary_pln', 'performance_score']]
print('QUERY - PRACOWNICY Z PENSJĄ > 12000 PLN:')
print(high_salary_query.head())
print()

print(f'Liczba pracowników z pensją > 12000 PLN: {len(high_salary)}')
# Out:
# WYBRANE KOLUMNY:
#   department     city  salary_pln  performance_score
# 0      sales  Wroclaw    12928.65               4.23
# 1         hr   Krakow     9648.33               3.28
# 2         hr   Poznan    10907.36               2.76
# 3        ops  Wroclaw    10229.72               3.06
# 4  analytics   Poznan     8448.04               2.60
#
# PRACOWNICY Z PENSJĄ > 12000 PLN:
#    department      city  salary_pln  performance_score
# 0       sales   Wroclaw    12928.65               4.23
# 5     product    Krakow    15048.89               4.48
# 6          it   Wroclaw    14225.72               3.22
# 7          it  Szczecin    13160.43               4.74
# 10   research   Wroclaw    12164.23               3.48
#
# LOC - PRACOWNICY Z PENSJĄ > 12000 PLN:
#    department      city  salary_pln  performance_score
# 0       sales   Wroclaw    12928.65               4.23
# 5     product    Krakow    15048.89               4.48
# 6          it   Wroclaw    14225.72               3.22
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 3</span>
#
# Użyj `loc` i `iloc`, aby pokazać różnicę między wyborem po etykietach i po pozycjach. Wyświetl 5 wybranych rekordów obiema metodami.
#
# Wymagane funkcje/parametry:
# - `loc[]` - wybiera dane po nazwach etykiet (indeks, kolumny).
# - `iloc[]` - wybiera dane po numerach pozycji.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html

# %%
# loc[] - wybór po etykietach (nazwach indeksu i kolumn)

print('LOC - wybór po etykietach (wiersze 0:4, wybrane kolumny):')
print(df.loc[0:4, ['employee_id', 'first_name', 'last_name', 'department', 'salary_pln']])
print()

# loc[] z warunkiem logicznym - wybieramy pracowników z działu 'it'
print('LOC - filtrowanie (department == "it"):')
print(df.loc[df['department'] == 'it', ['employee_id', 'first_name', 'last_name', 'salary_pln']])
print()

# iloc[] - wybór po pozycjach liczbowych (numerach wierszy i kolumn)
print('ILOC - wybór po pozycjach (wiersze 0:5, kolumny 0:5):')
print(df.iloc[0:5, 0:5])
print()

# iloc[] - wybór nieciągłych pozycji za pomocą listy
print('ILOC - wybór konkretnych pozycji wierszy [10, 20, 30, 40, 50] i kolumn [0, 2, 4]:')
print(df.iloc[[10, 20, 30, 40, 50], [0, 2, 4]])
print()

# Kluczowa różnica:
print('RÓŻNICA LOC vs ILOC przy zakresach:')
print('loc[0:4] - liczba wierszy:', len(df.loc[0:4]))   # 5 wierszy (0,1,2,3,4)
print('iloc[0:5] - liczba wierszy:', len(df.iloc[0:5]))  # 5 wierszy (0,1,2,3,4)
print('loc[0:4] vs iloc[0:4] - iloc NIE zawiera wiersza o pozycji 4:')
print('iloc[0:4] - liczba wierszy:', len(df.iloc[0:4]))  # 4 wiersze (0,1,2,3)
# Out:
# LOC - wybór po etykietach (wiersze 0:4, wybrane kolumny):
#    employee_id first_name  last_name department  salary_pln
# 0            1     Szymon  Zielinski      sales    12928.65
# 1            2      Marta   Kowalski         hr     9648.33
# 2            3        Iga  Kaczmarek         hr    10907.36
# 3            4    Roksana      Mazur        ops    10229.72
# 4            5     Celina  Kaczmarek  analytics     8448.04
#
# LOC - filtrowanie (department == "it"):
#      employee_id first_name  last_name  salary_pln
# 6              7     Daniel  Zielinski    14225.72
# 7              8        Iga      Mazur    13160.43
# 11            12     Tomasz      Mazur    14469.92
# 15            16     Alicja   Krawczyk    12269.76
# 27            28   Gabriela  Grabowska    14473.60
# ..           ...        ...        ...         ...
# 641          642        Iga  Kaczmarek    14108.90
# 658          659     Celina      Nowak    14415.59
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 4</span>
#
# Przekształć tabelę: zmień nazwę kolumny `salary_pln` na `salary`, dodaj kolumnę `annual_salary`, a następnie posortuj dane malejąco po `annual_salary`.
#
# Wymagane funkcje/parametry:
# - `rename()` - zmienia nazwę kolumny.
# - `assign()` albo przypisanie kolumny - dodaje nową kolumnę do tabeli.
# - `sort_values()` - sortuje rekordy według wartości w kolumnie.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

# %%
df_new = df.rename(columns={'salary_pln': 'salary'})

print('PO RENAME (salary_pln -> salary):')
print(df_new[['employee_id', 'department', 'salary']].head())
print()

# assign() dodaje nową kolumnę annual_salary (pensja roczna = miesięczna * 12).
# Zwraca nowy DataFrame bez modyfikacji oryginału.
df_new = df_new.assign(annual_salary=df_new['salary'] * 12)

print('PO ASSIGN (dodano annual_salary):')
print(df_new[['employee_id', 'department', 'salary', 'annual_salary']].head())
print()

# sort_values() sortuje dane malejąco po annual_salary.
# Parametr ascending=False ustawia sortowanie od największej do najmniejszej wartości.
df_sorted = df_new.sort_values('annual_salary', ascending=False)

print('PO SORTOWANIU MALEJĄCO (annual_salary):')
print(df_sorted[['employee_id', 'department', 'salary', 'annual_salary']].head(10))
print()

print(f'Najwyższa pensja roczna: {df_sorted["annual_salary"].iloc[0]:.2f} PLN')
print(f'Najniższa pensja roczna: {df_sorted["annual_salary"].iloc[-1]:.2f} PLN')
# Out:
# PO RENAME (salary_pln -> salary):
#    employee_id department    salary
# 0            1      sales  12928.65
# 1            2         hr   9648.33
# 2            3         hr  10907.36
# 3            4        ops  10229.72
# 4            5  analytics   8448.04
#
# PO ASSIGN (dodano annual_salary):
#    employee_id department    salary  annual_salary
# 0            1      sales  12928.65      155143.80
# 1            2         hr   9648.33      115779.96
# 2            3         hr  10907.36      130888.32
# 3            4        ops  10229.72      122756.64
# 4            5  analytics   8448.04      101376.48
#
# PO SORTOWANIU MALEJĄCO (annual_salary):
#      employee_id department    salary  annual_salary
# 646          647    product  20476.39      245716.68
# 263          264         it  19185.99      230231.88
# 191          192         it  18163.82      217965.84
# 630          631         it  17368.10      208417.20
# 367          368         it  16798.54      201582.48
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 5</span>
#
# Ustaw `employee_id` jako indeks, pokaż kilka rekordów, a potem przywróć zwykły indeks.
#
# Wymagane funkcje/parametry:
# - `set_index()` - ustawia wskazaną kolumnę jako indeks tabeli.
# - `reset_index()` - przywraca zwykły indeks liczbowy.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html

# %%
df_indexed = df.set_index('employee_id')

print('PO SET_INDEX (employee_id jako indeks):')
print(df_indexed[['first_name', 'last_name', 'department', 'salary_pln']].head())
print()
print('Indeks tabeli:', df_indexed.index.name)
print('Kolumny:', df_indexed.columns.tolist()[:5])
print()

print('LOC po employee_id (pracownik nr 10):')
print(df_indexed.loc[10, ['first_name', 'last_name', 'department', 'salary_pln']])
print()

df_reset = df_indexed.reset_index()

print('PO RESET_INDEX (powrót do indeksu liczbowego):')
print(df_reset[['employee_id', 'first_name', 'last_name', 'department', 'salary_pln']].head())
print()
print('Indeks tabeli po reset:', df_reset.index.name)
print('Kolumny:', df_reset.columns.tolist()[:5])
# Out:
# PO SET_INDEX (employee_id jako indeks):
#             first_name  last_name department  salary_pln
# employee_id
# 1               Szymon  Zielinski      sales    12928.65
# 2                Marta   Kowalski         hr     9648.33
# 3                  Iga  Kaczmarek         hr    10907.36
# 4              Roksana      Mazur        ops    10229.72
# 5               Celina  Kaczmarek  analytics     8448.04
#
# Indeks tabeli: employee_id
# Kolumny: ['first_name', 'last_name', 'department', 'city', 'age']
#
# LOC po employee_id (pracownik nr 10):
# first_name       Alicja
# last_name        Wojcik
# department    analytics
# salary_pln      9636.84
# Name: 10, dtype: object
#
# PO RESET_INDEX (powrót do indeksu liczbowego):
#    employee_id first_name  last_name department  salary_pln
# 0            1     Szymon  Zielinski      sales    12928.65
# 1            2      Marta   Kowalski         hr     9648.33
# 2            3        Iga  Kaczmarek         hr    10907.36
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 6</span>
#
# Policz liczebności działów i miast. Następnie oblicz średnią pensję i medianę pensji w podziale na `department`.
#
# Wymagane funkcje/parametry:
# - `value_counts()` - liczy częstość występowania wartości.
# - `groupby()` - dzieli dane na grupy według kolumny `department`.
# - `agg()` - pozwala policzyć kilka agregacji jednocześnie.
# - `mean()` - liczy średnią pensję.
# - `median()` - liczy medianę pensji.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %%
print('LICZEBNOŚCI DZIAŁÓW:')
print(df['department'].value_counts())
print()

print('LICZEBNOŚCI MIAST:')
print(df['city'].value_counts())
print()

summary = df.groupby('department').agg(
    liczba_pracownikow=('employee_id', 'count'),
    srednia_pensja=('salary_pln', 'mean'),
    mediana_pensji=('salary_pln', 'median'),
    min_pensja=('salary_pln', 'min'),
    max_pensja=('salary_pln', 'max')
)

summary = summary.sort_values('srednia_pensja', ascending=False)

print('ŚREDNIA I MEDIANA PENSJI WG DEPARTAMENTU:')
print(summary.round(2))
# Out:
# LICZEBNOŚCI DZIAŁÓW:
# department
# research     106
# it            96
# ops           93
# finance       88
# hr            83
# analytics     79
# sales         78
# product       77
# Name: count, dtype: int64
#
# LICZEBNOŚCI MIAST:
# city
# Lodz        108
# Wroclaw      97
# Szczecin     92
# Krakow       84
# Poznan       84
# Lublin       83
# Warszawa     77
# Gdansk       75
# Name: count, dtype: int64
#
# ŚREDNIA I MEDIANA PENSJI WG DEPARTAMENTU:
#             liczba_pracownikow  srednia_pensja  mediana_pensji  min_pensja  \
# department
# it                          96        14097.59        14098.66    10442.80
# product                     77        13024.91        12973.52     8278.03
# finance                     88        12623.75        12408.16     8474.93
# ops                         93        11448.98        11375.02     8374.95
# hr                          83        10956.58        11058.57     5647.16
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 7</span>
#
# Wczytaj `departments.csv` i połącz go z `employees.csv`. Sprawdź, czy każdy pracownik dostał poprawne dane działu.
#
# Wymagane funkcje/parametry:
# - `pd.read_csv()` - wczytuje dane z pliku CSV.
# - `merge()` - łączy tabele po wspólnym kluczu.
# - parametr `how` - określa typ złączenia (`left`, `inner`, `right`, `outer`).
# - parametr `indicator=True` - dodaje kolumnę pokazującą źródło dopasowania rekordów.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
departments = pd.read_csv('dane_lekcja3/departments.csv')

merged = employees.merge(departments, on='department', how='left', indicator=True)

print('WYNIK MERGE:')
print(merged.head(10))
print()

print('WERYFIKACJA DOPASOWANIA:')
print(merged['_merge'].value_counts())
print()

unmatched = merged[merged['_merge'] == 'left_only']
if len(unmatched) == 0:
    print('Każdy pracownik ma poprawnie przypisane dane działu.')
else:
    print(f'UWAGA: {len(unmatched)} pracowników nie ma dopasowanego działu:')
    print(unmatched[['employee_id', 'department']].head())

print()
print(f'Liczba wierszy po merge: {len(merged)} (oryginalna: {len(employees)})')
print(f'Kolumny po merge: {merged.columns.tolist()}')
# Out:
# WYNIK MERGE:
#    employee_id first_name   last_name department      city  age  salary_pln  \
# 0            1     Szymon   Zielinski      sales   Wroclaw   31    12928.65
# 1            2      Marta    Kowalski         hr    Krakow   25     9648.33
# 2            3        Iga   Kaczmarek         hr    Poznan   23    10907.36
# 3            4    Roksana       Mazur        ops   Wroclaw   55    10229.72
# 4            5     Celina   Kaczmarek  analytics    Poznan   57     8448.04
# 5            6   Gabriela   Kaczmarek    product    Krakow   38    15048.89
# 6            7     Daniel   Zielinski         it   Wroclaw   48    14225.72
# 7            8        Iga       Mazur         it  Szczecin   52    13160.43
# 8            9     Bartek  Piotrowski   research  Szczecin   45     9117.34
# 9           10     Alicja      Wojcik  analytics   Wroclaw   41     9636.84
#
#    bonus_pct  performance_score  projects_count  remote_days   hire_date  \
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 8</span>
#
# Wczytaj `employee_scores_wide.csv`, a następnie zamień układ szeroki na długi (`wide` -> `long`).
#
# Wymagane funkcje/parametry:
# - `pd.read_csv()` - wczytuje dane z pliku CSV.
# - `melt()` - zamienia wiele kolumn na układ długi z jedną kolumną nazw i jedną kolumną wartości.
# - parametr `id_vars` - wskazuje kolumny identyfikujące rekord.
# - parametr `var_name` - nadaje nazwę kolumnie z dawnymi nazwami kolumn.
# - parametr `value_name` - nadaje nazwę kolumnie z wartościami.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.melt.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.melt.html

# %%
scores = pd.read_csv('dane_lekcja3/employee_scores_wide.csv')

print('UKŁAD SZEROKI (wide):')
print(scores.head())
print(f'\nRozmiar (wide): {scores.shape}')
print(f'Kolumny: {scores.columns.tolist()}')
print()

scores_long = scores.melt(
    id_vars='employee_id',
    var_name='quarter',
    value_name='score'
)

print('UKŁAD DŁUGI (long):')
print(scores_long)
print(f'\nRozmiar (long): {scores_long.shape}')
print(f'Kolumny: {scores_long.columns.tolist()}')
print()

print('LICZBA WIERSZY NA PRACOWNIKA (powinno być 4 kwartały dla każdego):')
print(scores_long.groupby('employee_id').size().value_counts())
print()

print('UNIKALNE WARTOŚCI W KOLUMNIE quarter:')
print(scores_long['quarter'].unique())
# Out:
# UKŁAD SZEROKI (wide):
#    employee_id  score_q1  score_q2  score_q3  score_q4
# 0            1      56.9      96.9      66.7      86.6
# 1            2      73.6      61.1      74.2      97.1
# 2            3      73.8      51.7      53.9      99.3
# 3            4      86.8      94.2      88.1      79.5
# 4            5      62.0      50.7      99.0      80.2
#
# Rozmiar (wide): (500, 5)
# Kolumny: ['employee_id', 'score_q1', 'score_q2', 'score_q3', 'score_q4']
#
# UKŁAD DŁUGI (long):
#       employee_id   quarter  score
# 0               1  score_q1   56.9
# 1               2  score_q1   73.6
# 2               3  score_q1   73.8
# 3               4  score_q1   86.8
# 4               5  score_q1   62.0
# ...           ...       ...    ...
# 1995          496  score_q4   88.1
# 1996          497  score_q4   84.6
# 1997          498  score_q4   95.4
# 1998          499  score_q4   81.0
# 1999          500  score_q4   63.4
#
# [2000 rows x 3 columns]
#
# Rozmiar (long): (2000, 3)
# ...

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 9</span>
#
# Na podstawie `monthly_hours.csv` zbuduj tabelę przestawną pokazującą średnie `billable_hours` w podziale na `month` i `employee_id` albo `department` (po wcześniejszym merge).
#
# Wymagane funkcje/parametry:
# - `pd.read_csv()` - wczytuje dane z pliku CSV.
# - `merge()` - łączy tabelę godzin z inną tabelą, np. pracowników.
# - `pivot_table()` - buduje tabelę przestawną z agregacją.
# - parametr `index` - ustawia wiersze tabeli przestawnej.
# - parametr `columns` - ustawia kolumny tabeli przestawnej.
# - parametr `values` - wskazuje, którą zmienną agregować.
# - parametr `aggfunc` - określa, jaką funkcję agregującą zastosować.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %%
# tutaj dodaj swój kod

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 10</span>
#
# Wykorzystaj accessor `.str`: zamień `first_name` i `last_name` na małe litery, usuń spacje (jeśli są), a potem zbuduj kolumnę `full_name`.
#
# Wymagane funkcje/parametry:
# - `.str.lower()` - zamienia tekst na małe litery.
# - `.str.strip()` - usuwa zbędne spacje z początku i końca tekstu.
# - operacje na kolumnach tekstowych - pozwalają łączyć tekst z kilku kolumn w jedną nową kolumnę.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.str.lower.html
# - https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html

# %%
# tutaj dodaj swój kod

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 11</span>
#
# Wykorzystaj accessor `.dt`: zamień `hire_date` na typ daty, a potem wyciągnij rok zatrudnienia, miesiąc i nazwę dnia tygodnia.
#
# Wymagane funkcje/parametry:
# - `pd.to_datetime()` - konwertuje tekst na prawdziwy typ daty.
# - `.dt.year` - wyciąga rok z daty.
# - `.dt.month` - wyciąga numer miesiąca.
# - `.dt.day_name()` - zwraca nazwę dnia tygodnia.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
# - https://pandas.pydata.org/docs/reference/series.html#datetimelike-properties

# %%
# tutaj dodaj swój kod

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Zadanie 12</span>
#
# Przygotuj mini-podsumowanie `DataFrame`: jedna tabela agregacji + jedna tabela przestawna + 3 krótkie wnioski o danych pracowników.
#
# Wymagane funkcje/parametry:
# - `groupby()` - dzieli dane na grupy do dalszej agregacji.
# - `agg()` - pozwala policzyć kilka miar w jednym kroku.
# - `pivot_table()` - buduje tabelę przestawną do porównań.
# - `sort_values()` - porządkuje wynik, np. od najwyższej wartości.
# - `describe()` (opcjonalnie) - daje szybki statystyczny podgląd danych.
#
# Kryterium zaliczenia:
# - zadanie wykonane zgodnie z poleceniem,
# - wynik pokazany w notebooku.
#
# Checkpoint:
# - pokaż prowadzącemu wynik końcowy tej sekcji.
#
# Dokumentacja:
# - https://pandas.pydata.org/docs/reference/frame.html

# %%
# tutaj dodaj swój kod

# %% [markdown]
# ## <span style="color:#0f766e; font-weight:700;">Najczęstsze błędy</span>
#
# - mylenie `loc` i `iloc`,
# - filtrowanie bez nawiasów przy wielu warunkach,
# - nadpisywanie `DataFrame` bez kontroli, co zostało zmienione,
# - używanie `merge()` bez sprawdzenia kluczy,
# - zapominanie, że `.str` działa na tekście, a `.dt` na datach,
# - próba użycia `pivot_table()` bez jasnego określenia `index` i `values`.
